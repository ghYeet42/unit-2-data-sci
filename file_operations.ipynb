# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
#
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
listuh = open("states.txt")

# txt file is now listuh

for theStates in listuh:
        print(theStates)

#prints the list
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
#
# Pie charts or bar graphs would be good data collections to represent data because their may be mulitple of the same 2 letter abreviations representing states.
#
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
#
# Using a for loop and an if statement to sort the different abreviations into groups of how many of those abreviations there are and putting them into a place inside of a pie chart or bar graph
#
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
import matplotlib.pyplot as plt
from matplotlib import numpy as np



#loop to print the stuff in the text file

AL = 0
AK = 0
AZ = 0
AR = 0
AS = 0
CA = 0
CO = 0
CT = 0
DE = 0
DC = 0
FL = 0
GA = 0
GU = 0
HI = 0
IA = 0
ID = 0
IL = 0
IN = 0
KS = 0
KA = 0
KY = 0
LA = 0
MA = 0
MD = 0
ME = 0
MI = 0
MN = 0
MS = 0
MO = 0
MT = 0
NE = 0
NV = 0
KY = 0
NH = 0
NJ = 0
NM = 0
NY = 0
NC = 0
ND = 0
NP = 0
OH = 0
OK = 0
OR = 0
PA = 0
PR = 0
RI = 0
SC = 0
SD = 0
TN = 0
TX = 0
TT = 0
UT = 0
VT = 0
VA = 0
VI = 0
WA = 0
WV = 0
WI = 0
WY = 0

stateCounter = 0

#huge for loop to iterate through txt file and 

for item in listuh:
    if item == "AL\n":
        AL +=1
    elif item == "AK\n":
        AK +=1
    elif item == "AZ\n":
        AZ +=1
    elif item == "AR\n":
        AR +=1
    elif item == "AS\n":
        AS +=1
    elif item == "CA\n":
        CA +=1
    elif item == "CO\n":
        CO+=1
    elif item == "CT\n":
        CT +=1
    elif item == "DE\n":
        DE +=1
    elif item == "DC\n":
        DC +=1
    elif item == "FL\n":
        FL +=1
    elif item == "GA\n":
        GA +=1
    elif item == "GU\n":
        GU +=1
    elif item == "HI\n":
        HI +=1
    elif item == "IA\n":
        IA +=1
    elif item == "ID\n":
        ID +=1
    elif item == "IL\n":
        IL +=1
    elif item == "IN\n":
        IN +=1
    elif item == "KS\n":
        KS +=1
    elif item == "KA\n":
        KA +=1
    elif item == "LA\n":
        LA +=1
    elif item == "MD\n":
        MD +=1
    elif item == "MA\n":
        MA +=1
    elif item == "MI\n":
        MI +=1
    elif item == "MN\n":
        MN +=1
    elif item == "MS\n":
        MS +=1
    elif item == "MT\n":
        MT +=1
    elif item == "NE\n":
        NE +=1
    elif item == "NV\n":
        NV +=1
    elif item == "NH\n":
        NH +=1
    elif item == "NJ\n":
        NJ +=1
    elif item == "NY\n":
        NY +=1
    elif item == "NM\n":
        NM +=1
    elif item == "NC\n":
        NC +=1
    elif item == "ND\n":
        ND +=1
    elif item == "NP\n":
        NP +=1
    elif item == "OH\n":
        OH +=1
    elif item == "OK\n":
        OR +=1
    elif item == "OR\n":
        OR +=1
    elif item == "PA\n":
        PA +=1
    elif item == "PR\n":
        PR +=1
    elif item == "RI\n":
        RI +=1
    elif item == "SC\n":
        SC +=1
    elif item == "SD\n":
        SD +=1
    elif item == "TN\n":
        TN+=1
    elif item == "TX\n":
        TX+=1
    elif item == "TT\n":
        TT+=1
    elif item == "UT\n":
        UT +=1
    elif item == "VI\n":
        VI +=1
    elif item == "VT\n":
        VT +=1
    elif item == "WA\n":
        WA +=1
    elif item == "WV\n":
        WV +=1
    elif item == "WI\n":
        WI+=1
    elif item == "WY\n":
        WY+=1
    elif item == "KY\n":
        KY+=1

# x value for all states
x = ["AL", "AK", "AZ", "AR", "AS", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "GU", "HI", "IA", "ID", "IL", "IN", "KS", "KA", "KY", "LA", "MA", "MD" "ME", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "KY", "NH", "NJ", "NM", "NY", "NC", "ND" "NP", "OH", "OK", "OR", "PA", "PR", "RI", "SC", "SD" "TN", "TX", "TT", "UT", "VT", "VA", "VI", "WA", "WV", "WI", "WY"]


#y how many times each state appears
y = [0, 50, 100, 150, 200, 250, 300]



plt.style.use('_mpl-gallery')

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=50, linewidth=1, edgecolor="orange")

ax.set(xlim=(0, 8), xticks=np.arange(1, 50),
       ylim=(0, 56), yticks=np.linspace(0, 30, 6))

plt.rcParams["figure.figsize"] = (20, 15)

plt.show()
